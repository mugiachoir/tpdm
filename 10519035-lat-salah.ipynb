# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')
df.groupby('species')

# %%
y=df['petal_length'].loc[0:20]

plt.pie(y,labels=x,autopct='%1.1f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Mugia\DOCUMENT\TUGAS\Materi Semester 7\TPDM\Latihan\10519035-lat.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Mugia/DOCUMENT/TUGAS/Materi%20Semester%207/TPDM/Latihan/10519035-lat.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> y=df['petal_length'].loc[0:20]
# ----> <a href='vscode-notebook-cell:/d%3A/Mugia/DOCUMENT/TUGAS/Materi%20Semester%207/TPDM/Latihan/10519035-lat.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> plt.pie(y,labels=x,autopct='%1.1f%%')
#       <a href='vscode-notebook-cell:/d%3A/Mugia/DOCUMENT/TUGAS/Materi%20Semester%207/TPDM/Latihan/10519035-lat.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> plt.show()
#
# NameError: name 'x' is not defined

# %%
plt.plot( x, y, marker='*', ) 
plt.title('Hubungan sepal length dan petal length') 
plt.ylabel('Petal length') 
plt.xlabel('Sepal length') 
plt.show()

# %%
x_coords = np.arange(len(x)) 
plt.bar(x_coords, y) 
plt.show()

# %%
cities = ['Tokyo', 'Delhi', 'Shanghai', 'Sao Paulo', 'Mumbai', 'Mexico City', 'Beijing', 'Osaka', 'Cairo', 'New York', 'Dhaka', 'Karachi']
months = ['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'] 
temperatures = [ [df['sepal_length'].groupby(df['sepal_length'])],
               ]
z=df['petal_width'].loc[0:20]
sns.heatmap(z, yticklabels=y, xticklabels=x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Mugia\DOCUMENT\TUGAS\Materi Semester 7\TPDM\Latihan\10519035-lat.ipynb Cell 6 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/d%3A/Mugia/DOCUMENT/TUGAS/Materi%20Semester%207/TPDM/Latihan/10519035-lat.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> temperatures = [ [df['sepal_length'].groupby(df['sepal_length'])],
#       <a href='vscode-notebook-cell:/d%3A/Mugia/DOCUMENT/TUGAS/Materi%20Semester%207/TPDM/Latihan/10519035-lat.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>                ]
#       <a href='vscode-notebook-cell:/d%3A/Mugia/DOCUMENT/TUGAS/Materi%20Semester%207/TPDM/Latihan/10519035-lat.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> z=df['petal_width'].loc[0:20]
# ...
